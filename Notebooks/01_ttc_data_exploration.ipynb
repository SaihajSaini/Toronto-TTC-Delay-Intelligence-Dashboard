# %%
print("TTC Data Analysis Started")
# Out:
# TTC Data Analysis Started

# %%
import pandas as pd

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ['ttc_subway_delays.csv']

# %%
import os

os.listdir("../data/raw")
# Out:
# ['ttc_subway_delays.csv']

# %%
df = pd.read_csv("../data/raw/TTC Subway Delay Data since 2025.csv")

# %%
df.head()
# Out:
#    _id        Date   Time        Day            Station   Code  Min Delay  \
# 0    1  2025-01-01  02:10  Wednesday   BATHURST STATION  MUSAN          5
# 1    2  2025-01-01  02:30  Wednesday     DUNDAS STATION  MUIRS          0
# 2    3  2025-01-01  02:32  Wednesday  BROADVIEW STATION  PUMST          0
# 3    4  2025-01-01  02:58  Wednesday      KEELE STATION   EUSC          0
# 4    5  2025-01-01  02:58  Wednesday    COXWELL STATION   SUAE          0
#
#    Min Gap Bound Line  Vehicle
# 0        9     E   BD     5227
# 1        0   NaN   YU        0
# 2        0     E   BD        0
# 3        0     W   BD     5293
# 4        0   NaN   BD        0

# %%
df.shape
# Out:
# (38018, 11)

# %%
df.columns
# Out:
# Index(['_id', 'Date', 'Time', 'Day', 'Station', 'Code', 'Min Delay', 'Min Gap',
#        'Bound', 'Line', 'Vehicle'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38018 entries, 0 to 38017
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        38018 non-null  int64
#  1   Date       38018 non-null  str
#  2   Time       38018 non-null  str
#  3   Day        38018 non-null  str
#  4   Station    38018 non-null  str
#  5   Code       38018 non-null  str
#  6   Min Delay  38018 non-null  int64
#  7   Min Gap    38018 non-null  int64
#  8   Bound      24592 non-null  str
#  9   Line       37891 non-null  str
#  10  Vehicle    38018 non-null  int64
# dtypes: int64(4), str(7)
# memory usage: 3.2 MB

# %%
df.isnull().sum()
# Out:
# _id              0
# Date             0
# Time             0
# Day              0
# Station          0
# Code             0
# Min Delay        0
# Min Gap          0
# Bound        13426
# Line           127
# Vehicle          0
# dtype: int64

# %%
df[df["Line"].isnull()]
# Out:
#          _id        Date   Time        Day                 Station   Code  \
# 577      578  2025-01-09  17:55   Thursday     BATHURST AND DUPONT   MUIE
# 951      952  2025-01-15  11:56  Wednesday            MCCOWAN YARD    SUO
# 1065    1066  2025-01-16  00:55   Thursday                ST CLAIR   MUIS
# 1162    1163  2025-01-18  14:43   Saturday  SCABOROUGH TOWN CENTRE  PUMEL
# 1606    1607  2025-01-24  01:09     Friday     GREENWOOD CAR HOUSE    SUG
# ...      ...         ...    ...        ...                     ...    ...
# 37439  37440  2026-05-24  00:15     Sunday  KIPLING STATION PLATFO    MUI
# 37475  37476  2026-05-25  10:24     Monday          GREENWOOD SHOP   MUIE
# 37860  37861  2026-05-29  22:02     Friday             MARKDALE EE    SUO
# 37973  37974  2026-05-31  13:40     Sunday             MARKDALE EE    MUO
# 38010  38011  2026-05-31  23:40     Sunday          GREENWOOD YARD   MUSE
#
#        Min Delay  Min Gap Bound Line  Vehicle
# ...

# %%
df[df["Bound"].isnull()].head()
# Out:
#     _id        Date   Time        Day          Station   Code  Min Delay  \
# 1     2  2025-01-01  02:30  Wednesday   DUNDAS STATION  MUIRS          0
# 4     5  2025-01-01  02:58  Wednesday  COXWELL STATION   SUAE          0
# 10   11  2025-01-01  09:58  Wednesday   WILSON STATION   MUIS          0
# 19   20  2025-01-01  15:07  Wednesday    FINCH STATION  MUPLC          0
# 22   23  2025-01-01  16:04  Wednesday   WILSON STATION   MUIS          0
#
#     Min Gap Bound Line  Vehicle
# 1         0   NaN   YU        0
# 4         0   NaN   BD        0
# 10        0   NaN   YU        0
# 19        0   NaN   YU        0
# 22        0   NaN   YU        0

# %%
df[df["Line"].isnull()]
# Out:
#          _id        Date   Time        Day                 Station   Code  \
# 577      578  2025-01-09  17:55   Thursday     BATHURST AND DUPONT   MUIE
# 951      952  2025-01-15  11:56  Wednesday            MCCOWAN YARD    SUO
# 1065    1066  2025-01-16  00:55   Thursday                ST CLAIR   MUIS
# 1162    1163  2025-01-18  14:43   Saturday  SCABOROUGH TOWN CENTRE  PUMEL
# 1606    1607  2025-01-24  01:09     Friday     GREENWOOD CAR HOUSE    SUG
# ...      ...         ...    ...        ...                     ...    ...
# 37439  37440  2026-05-24  00:15     Sunday  KIPLING STATION PLATFO    MUI
# 37475  37476  2026-05-25  10:24     Monday          GREENWOOD SHOP   MUIE
# 37860  37861  2026-05-29  22:02     Friday             MARKDALE EE    SUO
# 37973  37974  2026-05-31  13:40     Sunday             MARKDALE EE    MUO
# 38010  38011  2026-05-31  23:40     Sunday          GREENWOOD YARD   MUSE
#
#        Min Delay  Min Gap Bound Line  Vehicle
# ...

# %%
df.nunique()
# Out:
# _id          38018
# Date           516
# Time          1437
# Day              7
# Station       1150
# Code           137
# Min Delay      131
# Min Gap        131
# Bound            5
# Line            33
# Vehicle        844
# dtype: int64

# %%
df["Code"].value_counts().head(10)
# Out:
# Code
# SUDP     4414
# MUIS     3528
# SUO      2845
# MUPAA    1980
# PUOPO    1923
# MUIRS    1681
# MUIR     1319
# MUO      1292
# MUSC     1262
# PUMEL    1171
# Name: count, dtype: int64

# %%
df["Min Delay"].describe()
# Out:
# count    38018.000000
# mean         2.829476
# std         13.671101
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          4.000000
# max        900.000000
# Name: Min Delay, dtype: float64

# %%
df["Code"].value_counts().head(10)
# Out:
# Code
# SUDP     4414
# MUIS     3528
# SUO      2845
# MUPAA    1980
# PUOPO    1923
# MUIRS    1681
# MUIR     1319
# MUO      1292
# MUSC     1262
# PUMEL    1171
# Name: count, dtype: int64

# %%
df["Min Delay"].describe()
# Out:
# count    38018.000000
# mean         2.829476
# std         13.671101
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          4.000000
# max        900.000000
# Name: Min Delay, dtype: float64

# %%
import matplotlib.pyplot as plt

top_codes = df["Code"].value_counts().head(10)

top_codes.plot(kind="bar", figsize=(10,5))

plt.title("Top 10 TTC Delay Causes")
plt.xlabel("Delay Code")
plt.ylabel("Number of Incidents")

plt.show()

# %%
top_stations = df["Station"].value_counts().head(10)

top_stations
# Out:
# Station
# BLOOR STATION         1477
# FINCH STATION         1276
# KENNEDY BD STATION    1234
# KIPLING STATION       1208
# EGLINTON STATION       954
# YONGE BD STATION       890
# WILSON STATION         825
# VMC STATION            790
# UNION STATION          754
# WARDEN STATION         726
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

top_stations.plot(kind="bar", figsize=(10,5))

plt.title("Top 10 TTC Locations With Most Delay Incidents")
plt.xlabel("Station")
plt.ylabel("Number of Delays")

plt.xticks(rotation=45)

plt.show()

# %%
clean_df = df.copy()

# %%
clean_df = clean_df.drop(columns=["_id"])

# %%
clean_df = clean_df.rename(columns={
    "Min Delay": "Min_Delay",
    "Min Gap": "Min_Gap"
})

# %%
clean_df["Date"] = pd.to_datetime(clean_df["Date"])

# %%
clean_df["Bound"] = clean_df["Bound"].fillna("Unknown")

clean_df["Line"] = clean_df["Line"].fillna("Unknown")

# %%
clean_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38018 entries, 0 to 38017
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       38018 non-null  datetime64[us]
#  1   Time       38018 non-null  str
#  2   Day        38018 non-null  str
#  3   Station    38018 non-null  str
#  4   Code       38018 non-null  str
#  5   Min_Delay  38018 non-null  int64
#  6   Min_Gap    38018 non-null  int64
#  7   Bound      38018 non-null  str
#  8   Line       38018 non-null  str
#  9   Vehicle    38018 non-null  int64
# dtypes: datetime64[us](1), int64(3), str(6)
# memory usage: 2.9 MB

# %%
clean_df.isnull().sum()
# Out:
# Date         0
# Time         0
# Day          0
# Station      0
# Code         0
# Min_Delay    0
# Min_Gap      0
# Bound        0
# Line         0
# Vehicle      0
# dtype: int64

# %%
clean_df["Month"] = clean_df["Date"].dt.month_name()

# %%
monthly_delays = clean_df["Month"].value_counts()

monthly_delays
# Out:
# Month
# April        4836
# May          4808
# January      4587
# March        4386
# February     4322
# August       2719
# December     2242
# November     2215
# July         2122
# October      2027
# June         1941
# September    1813
# Name: count, dtype: int64

# %%
month_order = [
    "January",
    "February",
    "March",
    "April",
    "May",
    "June",
    "July",
    "August",
    "September",
    "October",
    "November",
    "December"
]

monthly_delays = monthly_delays.reindex(month_order)

monthly_delays
# Out:
# Month
# January      4587
# February     4322
# March        4386
# April        4836
# May          4808
# June         1941
# July         2122
# August       2719
# September    1813
# October      2027
# November     2215
# December     2242
# Name: count, dtype: int64

# %%
clean_df.to_csv("../data/processed/ttc_delays_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 clean_df.to_csv("../data/processed/ttc_delays_cleaned.csv", index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:3976, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3972             float_format=float_format,
#    3973             decimal=decimal,
#    3974         )
#    3975
# -> 3976         return DataFrameRenderer(formatter).to_csv(
#    3977             path_or_buf,
#    3978             lineterminator=lineterminator,
#    3979             sep=sep,
#
# ...

# %%
import os

os.getcwd()
# Out:
# '/Users/saihajs/Documents/Data Analyst Projects/TTC - DELAY /Notebooks'

# %%
import os

os.listdir("../data")
# Out:
# ['.DS_Store', 'Raw']

# %%
os.mkdir("../data/processed")

# %%
clean_df.to_csv("../data/processed/ttc_delays_cleaned.csv", index=False)

# %%
os.listdir("../data/processed")
# Out:
# ['ttc_delays_cleaned.csv']

# %%
clean_df.head()
# Out:
#         Date   Time        Day            Station   Code  Min_Delay  Min_Gap  \
# 0 2025-01-01  02:10  Wednesday   BATHURST STATION  MUSAN          5        9
# 1 2025-01-01  02:30  Wednesday     DUNDAS STATION  MUIRS          0        0
# 2 2025-01-01  02:32  Wednesday  BROADVIEW STATION  PUMST          0        0
# 3 2025-01-01  02:58  Wednesday      KEELE STATION   EUSC          0        0
# 4 2025-01-01  02:58  Wednesday    COXWELL STATION   SUAE          0        0
#
#      Bound Line  Vehicle
# 0        E   BD     5227
# 1  Unknown   YU        0
# 2        E   BD        0
# 3        W   BD     5293
# 4  Unknown   BD        0

# %%
clean_df.columns
# Out:
# Index(['Date', 'Time', 'Day', 'Station', 'Code', 'Min_Delay', 'Min_Gap',
#        'Bound', 'Line', 'Vehicle'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

monthly_delays.plot(
    kind="line",
    figsize=(10,5),
    marker="o"
)

plt.title("TTC Delay Incidents by Month")
plt.xlabel("Month")
plt.ylabel("Number of Delays")

plt.xticks(rotation=45)

plt.show()

# %%
clean_df["Time"].head()
# Out:
# 0    02:10
# 1    02:30
# 2    02:32
# 3    02:58
# 4    02:58
# Name: Time, dtype: str

# %%
clean_df["Hour"] = pd.to_datetime(clean_df["Time"], format="%H:%M").dt.hour

# %%
clean_df[["Time", "Hour"]].head()
# Out:
#     Time  Hour
# 0  02:10     2
# 1  02:30     2
# 2  02:32     2
# 3  02:58     2
# 4  02:58     2

# %%
hourly_delays = clean_df["Hour"].value_counts().sort_index()

hourly_delays
# Out:
# Hour
# 0     1321
# 1     1422
# 2      887
# 3      237
# 4      202
# 5     1451
# 6     1738
# 7     1741
# 8     2225
# 9     1671
# 10    1454
# 11    1592
# 12    1672
# 13    1707
# 14    1741
# 15    1853
# 16    2081
# 17    2086
# 18    1998
# 19    1613
# 20    1635
# 21    1637
# 22    2242
# 23    1812
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

hourly_delays.plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("TTC Delay Incidents by Hour of Day")
plt.xlabel("Hour")
plt.ylabel("Number of Delays")

plt.show()

# %%
avg_delay_station = (
    clean_df.groupby("Station")["Min_Delay"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

avg_delay_station
# Out:
# Station
# WOODBINE STATION - KEN    827.0
# ST CLAIR & BLOOR          708.0
# EGLINTON AND BLOOR STA    504.0
# SHEPPARD TO EGLINTON      480.0
# COXWELL STATION APPROA    184.0
# KING TO UNION             138.0
# DONLANDS TO GREENWOOD     129.0
# WILSON                     78.0
# UNION STATION (TO VMC)     70.0
# YORKDALE TO WILSON         65.0
# Name: Min_Delay, dtype: float64

# %%
worst_delays = clean_df.sort_values(
    by="Min_Delay",
    ascending=False
).head(10)

worst_delays
# Out:
#             Date   Time      Day                 Station   Code  Min_Delay  \
# 3320  2025-02-16  11:03   Sunday   SHEPPARD WEST STATION  MUWEA        900
# 27655 2026-01-26  05:50   Monday  WOODBINE STATION - KEN  PUTIS        827
# 3308  2025-02-16  09:18   Sunday        EGLINTON STATION  MUWEA        807
# 27657 2026-01-26  05:54   Monday        ST CLAIR & BLOOR  MUWEA        708
# 27580 2026-01-25  15:21   Sunday   VICTORIA PARK STATION  PUTIS        661
# 27587 2026-01-25  16:12   Sunday       GLENCAIRN STATION  PUTIS        622
# 27658 2026-01-26  06:00   Monday   ST CLAIR WEST STATION  PUTIS        505
# 27598 2026-01-25  17:32   Sunday  EGLINTON AND BLOOR STA  MUWEA        504
# 33155 2026-04-07  05:46  Tuesday        OLD MILL STATION   EUVE        484
# 27661 2026-01-26  06:39   Monday       ISLINGTON STATION  PUTIS        481
#
#        Min_Gap Bound Line  Vehicle     Month  Hour
# 3320       906     N   YU     5496  February    11
# ...

# %%
clean_df["Min_Delay"].describe()
# Out:
# count    38018.000000
# mean         2.829476
# std         13.671101
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          4.000000
# max        900.000000
# Name: Min_Delay, dtype: float64

# %%
worst_delays
# Out:
#             Date   Time      Day                 Station   Code  Min_Delay  \
# 3320  2025-02-16  11:03   Sunday   SHEPPARD WEST STATION  MUWEA        900
# 27655 2026-01-26  05:50   Monday  WOODBINE STATION - KEN  PUTIS        827
# 3308  2025-02-16  09:18   Sunday        EGLINTON STATION  MUWEA        807
# 27657 2026-01-26  05:54   Monday        ST CLAIR & BLOOR  MUWEA        708
# 27580 2026-01-25  15:21   Sunday   VICTORIA PARK STATION  PUTIS        661
# 27587 2026-01-25  16:12   Sunday       GLENCAIRN STATION  PUTIS        622
# 27658 2026-01-26  06:00   Monday   ST CLAIR WEST STATION  PUTIS        505
# 27598 2026-01-25  17:32   Sunday  EGLINTON AND BLOOR STA  MUWEA        504
# 33155 2026-04-07  05:46  Tuesday        OLD MILL STATION   EUVE        484
# 27661 2026-01-26  06:39   Monday       ISLINGTON STATION  PUTIS        481
#
#        Min_Gap Bound Line  Vehicle     Month  Hour
# 3320       906     N   YU     5496  February    11
# ...

# %%
clean_df[clean_df["Min_Delay"] > 60].shape
# Out:
# (104, 12)

# %%
clean_df[clean_df["Min_Delay"] > 60]["Min_Delay"].describe()
# Out:
# count    104.000000
# mean     171.211538
# std      177.583601
# min       61.000000
# 25%       78.000000
# 50%      100.500000
# 75%      157.750000
# max      900.000000
# Name: Min_Delay, dtype: float64

# %%
clean_df[clean_df["Min_Delay"] > 60].shape
# Out:
# (104, 12)

# %%
clean_df[clean_df["Min_Delay"] > 60]["Min_Delay"].describe()
# Out:
# count    104.000000
# mean     171.211538
# std      177.583601
# min       61.000000
# 25%       78.000000
# 50%      100.500000
# 75%      157.750000
# max      900.000000
# Name: Min_Delay, dtype: float64

# %%
clean_df["Delay_Category"] = pd.cut(
    clean_df["Min_Delay"],
    bins=[-1, 5, 30, 60, float("inf")],
    labels=["Minor", "Moderate", "Major", "Severe"]
)

# %%
clean_df["Delay_Category"].value_counts()
# Out:
# Delay_Category
# Minor       32985
# Moderate     4743
# Major         186
# Severe        104
# Name: count, dtype: int64

# %%
clean_df[clean_df["Min_Delay"] > 60]["Min_Delay"].describe()
# Out:
# count    104.000000
# mean     171.211538
# std      177.583601
# min       61.000000
# 25%       78.000000
# 50%      100.500000
# 75%      157.750000
# max      900.000000
# Name: Min_Delay, dtype: float64

# %%
clean_df["Delay_Category"] = pd.cut(
    clean_df["Min_Delay"],
    bins=[-1, 5, 30, 60, float("inf")],
    labels=["Minor", "Moderate", "Major", "Severe"]
)

# %%
clean_df["Delay_Category"].value_counts()
# Out:
# Delay_Category
# Minor       32985
# Moderate     4743
# Major         186
# Severe        104
# Name: count, dtype: int64

# %%
clean_df["Delay_Category"].value_counts()
# Out:
# Delay_Category
# Minor       32985
# Moderate     4743
# Major         186
# Severe        104
# Name: count, dtype: int64

# %%
total_delays = len(clean_df)

total_delays
# Out:
# 38018

# %%
average_delay = clean_df["Min_Delay"].mean()

average_delay
# Out:
# np.float64(2.8294755115997687)

# %%
median_delay = clean_df["Min_Delay"].median()

median_delay
# Out:
# np.float64(0.0)

# %%
severe_delays = (clean_df["Delay_Category"] == "Severe").sum()

severe_delays
# Out:
# np.int64(104)

# %%
positive_delays = clean_df[clean_df["Min_Delay"] > 0]

positive_delays["Min_Delay"].mean()
# Out:
# np.float64(8.009754281459418)

# %%
positive_delays["Min_Delay"].median()
# Out:
# np.float64(5.0)

# %%
positive_delays = clean_df[clean_df["Min_Delay"] > 0]

positive_delays["Min_Delay"].mean()
# Out:
# np.float64(8.009754281459418)

# %%
positive_delays["Min_Delay"].median()
# Out:
# np.float64(5.0)

# %%
positive_delays["Min_Delay"].median()
# Out:
# np.float64(5.0)

# %%
severity_counts = clean_df["Delay_Category"].value_counts()

severity_counts
# Out:
# Delay_Category
# Minor       32985
# Moderate     4743
# Major         186
# Severe        104
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

severity_counts.plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("TTC Delay Severity Distribution")
plt.xlabel("Delay Category")
plt.ylabel("Number of Incidents")

plt.xticks(rotation=45)

plt.show()

# %%
clean_df["Delay_Category"].value_counts()
# Out:
# Delay_Category
# Minor       32985
# Moderate     4743
# Major         186
# Severe        104
# Name: count, dtype: int64

# %%
top_station_delays = (
    clean_df["Station"]
    .value_counts()
    .head(10)
)

top_station_delays
# Out:
# Station
# BLOOR STATION         1477
# FINCH STATION         1276
# KENNEDY BD STATION    1234
# KIPLING STATION       1208
# EGLINTON STATION       954
# YONGE BD STATION       890
# WILSON STATION         825
# VMC STATION            790
# UNION STATION          754
# WARDEN STATION         726
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

top_station_delays.sort_values().plot(
    kind="barh",
    figsize=(10,6)
)

plt.title("Top 10 TTC Stations by Delay Incidents")
plt.xlabel("Number of Delay Incidents")
plt.ylabel("Station")

plt.show()

# %%
import matplotlib.pyplot as plt

top_station_delays.sort_values().plot(
    kind="barh",
    figsize=(10,6)
)

plt.title("Top 10 TTC Stations by Delay Incidents")
plt.xlabel("Number of Delay Incidents")
plt.ylabel("Station")

plt.show()

# %%
top_delay_codes = clean_df["Code"].value_counts().head(10)

top_delay_codes
# Out:
# Code
# SUDP     4414
# MUIS     3528
# SUO      2845
# MUPAA    1980
# PUOPO    1923
# MUIRS    1681
# MUIR     1319
# MUO      1292
# MUSC     1262
# PUMEL    1171
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

top_delay_codes.sort_values().plot(
    kind="barh",
    figsize=(10,6)
)

plt.title("Top 10 Causes of TTC Delays")
plt.xlabel("Number of Incidents")
plt.ylabel("Delay Code")

plt.show()

# %%
top_delay_codes.sum()
# Out:
# np.int64(21415)

# %%
top_delay_codes.sum() / len(clean_df) * 100
# Out:
# np.float64(56.32858119837971)

# %%
import matplotlib.pyplot as plt

top_delay_codes.sort_values().plot(
    kind="barh",
    figsize=(10,6)
)

plt.title("Top 10 TTC Delay Causes")
plt.xlabel("Number of Incidents")
plt.ylabel("Delay Code")

plt.show()
